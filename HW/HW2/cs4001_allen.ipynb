# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/cyneuro/CI-BioEng-Class/blob/main/cs4001_allen.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Downloading and building cells from AllenDB
#
# <div class="alert alert-warning">
#   <strong>Warning:</strong> As of September 2025, `allensdk` is not runnable on Python 3.12 which is now default in Google Colab. We recommend using this notebook in a local conda environment with `python=3.10`.
# </div>
#
# Useful links:
# 1. [Database](http://celltypes.brain-map.org/data)
# 2. [Downloading biophysical models](https://allensdk.readthedocs.io/en/latest/biophysical_models.html)
# 3. [Example on building cells](https://alleninstitute.github.io/AllenSDK/_static/examples/nb/pulse_stimulus.html)

# %%
# !pip install --upgrade pip
# !pip install --quiet allensdk neuron
# Out:
# Requirement already satisfied: pip in /home/hrbncv/miniconda3/envs/BMTK/lib/python3.9/site-packages (25.2)

# %%
from allensdk.api.queries.biophysical_api import BiophysicalApi
from allensdk.model.biophys_sim.config import Config
from allensdk.model.biophysical.utils import Utils

import matplotlib.pyplot as plt

# %% [markdown]
# ## Download the cell

# %%
bp = BiophysicalApi()

# Mouse Layer 5 Primary visual area neuron
# http://celltypes.brain-map.org/experiment/electrophysiology/488683425
bp.get_neuronal_models(488683425)
# Out:
# [{'id': 491766131,
#   'name': 'Biophysical - all active_Rbp4-Cre_KL100;Ai14-203503.04.01.01',
#   'neuron_reconstruction_id': 527109145,
#   'neuronal_model_template_id': 491455321,
#   'specimen_id': 488683425}]

# %%
# Download the cell with passive dendrites
bp.cache_stimulus = False # Change to False to not download the large stimulus NWB file
bp.cache_data(491766131) # 'id'
# Out:
# 2025-09-20 19:34:27,103 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/527109147
# 2025-09-20 19:34:27,496 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/527109161
# 2025-09-20 19:34:27,686 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337019
# 2025-09-20 19:34:27,878 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337225
# 2025-09-20 19:34:28,070 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337054
# 2025-09-20 19:34:28,266 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337070
# 2025-09-20 19:34:28,473 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/491113425
# 2025-09-20 19:34:28,697 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337062
# 2025-09-20 19:34:28,838 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337293
# 2025-09-20 19:34:28,976 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337007
# 2025-09-20 19:34:29,183 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/464138096
# 2025-09-20 19:34:29,366 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337066
# 2025-09-20 19:34:29,583 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337015
# 2025-09-20 19:34:29,721 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337011
# 2025-09-20 19:34:29,854 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337046
# 2025-09-20 19:34:29,987 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337042
# 2025-09-20 19:34:30,129 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337050
# 2025-09-20 19:34:30,301 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337003
# 2025-09-20 19:34:30,442 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/569956135

# %% [markdown]
# ## Build the cell

# %%
# Compile the modfiles
# !nrnivmodl modfiles

# Create the h object
description = Config().load('manifest.json')
utils = Utils(description)
h = utils.h

# Convert all "value" attributes to floats
for dict in utils.description.data['genome']:
    for key, value in dict.items():
        if key == 'value': dict[key] = float(value)
# Out:
# /home/hrbncv/miniconda3/envs/BMTK/bin/nrnivmodl:10: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import working_set
# /home/hrbncv/CI_8001/HW/HW2
# Mod files: "modfiles/modfiles/CaDynamics.mod" "modfiles/modfiles/Ca_HVA.mod" "modfiles/modfiles/Ca_LVA.mod" "modfiles/modfiles/Ih.mod" "modfiles/modfiles/Im.mod" "modfiles/modfiles/Im_v2.mod" "modfiles/modfiles/Kd.mod" "modfiles/modfiles/K_P.mod" "modfiles/modfiles/K_T.mod" "modfiles/modfiles/Kv2like.mod" "modfiles/modfiles/Kv3_1.mod" "modfiles/modfiles/Nap.mod" "modfiles/modfiles/NaTa.mod" "modfiles/modfiles/NaTs.mod" "modfiles/modfiles/NaV.mod" "modfiles/modfiles/SK.mod"
#
# Creating 'x86_64' directory for .o files.
#
#  -> Compiling mod_func.cpp
#  -> NMODL ../modfiles/CaDynamics.mod
#  -> NMODL ../modfiles/Ca_HVA.mod
#  -> NMODL ../modfiles/Ca_LVA.mod
# Translating CaDynamics.mod into /home/hrbncv/CI_8001/HW/HW2/x86_64/CaDynamics.c
# Translating Ca_HVA.mod into /home/hrbncv/CI_8001/HW/HW2/x86_64/Ca_HVA.c
#  -> NMODL ../modfiles/Ih.mod
# Translating Ca_LVA.mod into /home/hrbncv/CI_8001/HW/HW2/x86_64/Ca_LVA.c
# Thread Safe
# Thread Safe
# Thread Safe
#  -> NMODL ../modfiles/Im.mod
#  -> NMODL ../modfiles/Im_v2.mod
#  -> NMODL ../modfiles/Kd.mod
# Translating Ih.mod into /home/hrbncv/CI_8001/HW/HW2/x86_64/Ih.c
# Thread Safe
# Translating Im.mod into /home/hrbncv/CI_8001/HW/HW2/x86_64/Im.c
# Translating Im_v2.mod into /home/hrbncv/CI_8001/HW/HW2/x86_64/Im_v2.c
#  -> NMODL ../modfiles/K_P.mod
# Translating Kd.mod into /home/hrbncv/CI_8001/HW/HW2/x86_64/Kd.c
# Thread Safe
# Thread Safe
# Thread Safe
#  -> NMODL ../modfiles/K_T.mod
#  -> NMODL ../modfiles/Kv2like.mod
# Translating K_P.mod into /home/hrbncv/CI_8001/HW/HW2/x86_64/K_P.c
#  -> NMODL ../modfiles/Kv3_1.mod
# Thread Safe
# Translating K_T.mod into /home/hrbncv/CI_8001/HW/HW2/x86_64/K_T.c
# Translating Kv2like.mod into /home/hrbncv/CI_8001/HW/HW2/x86_64/Kv2like.c
#  -> NMODL ../modfiles/Nap.mod
# Translating Kv3_1.mod into /home/hrbncv/CI_8001/HW/HW2/x86_64/Kv3_1.c
# Thread Safe
# Thread Safe
# Thread Safe
#  -> NMODL ../modfiles/NaTa.mod
# Translating Nap.mod into /home/hrbncv/CI_8001/HW/HW2/x86_64/Nap.c
#  -> NMODL ../modfiles/NaTs.mod
#  -> NMODL ../modfiles/NaV.mod
# Thread Safe
# Translating NaTa.mod into /home/hrbncv/CI_8001/HW/HW2/x86_64/NaTa.c
#  -> NMODL ../modfiles/SK.mod
# Translating NaV.mod into /home/hrbncv/CI_8001/HW/HW2/x86_64/NaV.c
# Translating NaTs.mod into /home/hrbncv/CI_8001/HW/HW2/x86_64/NaTs.c
# Thread Safe
# Thread Safe
# NEURON's CVode method ignores conservation
# Notice: LINEAR is not thread safe.
#  -> Compiling CaDynamics.c
# Translating SK.mod into /home/hrbncv/CI_8001/HW/HW2/x86_64/SK.c
#  -> Compiling Ca_HVA.c
# Thread Safe
#  -> Compiling Ca_LVA.c
#  -> Compiling Ih.c
#  -> Compiling Im.c
#  -> Compiling Im_v2.c
#  -> Compiling Kd.c
#  -> Compiling K_P.c
#  -> Compiling K_T.c
#  -> Compiling Kv2like.c
#  -> Compiling Kv3_1.c
#  -> Compiling Nap.c
#  -> Compiling NaTa.c
#  -> Compiling NaTs.c
#  -> Compiling NaV.c
#  -> Compiling SK.c
#  => LINKING shared library ./libnrnmech.so
#  => LINKING executable ./special LDFLAGS are:    -pthread
# Successfully created x86_64/special
# Warning: no DISPLAY environment variable.
# --No graphics will be displayed.

# %%
# Configure morphology
manifest = description.manifest
morphology_path = description.manifest.get_path('MORPHOLOGY')
utils.generate_morphology(morphology_path.encode('ascii', 'ignore'))

# Specify passive properties
passive = {
      "ra": 100,
      "cm": [
        {
          "section": "soma",
          "cm": 1
        },
        {
          "section": "axon",
          "cm": 1
        },
        {
          "section": "dend",
          "cm": 1
        },
        {
          "section": "apic",
          "cm": 1
        }
      ],
      "e_pas": -65.75
}
utils.description.data["passive"][0] = passive
utils.load_cell_parameters()

# %%
# Set current injection
stim = h.IClamp(h.soma[0](0.5))
stim.amp = 1.0
stim.delay = 100.0
stim.dur = 800.0
h.tstop = 1000.0

# %%
vec = utils.record_values()

# %%
h.finitialize()
h.run()
# Out:
# 0.0

# %%
plt.plot(vec['t'].as_numpy(), vec['v'].as_numpy())
plt.xlabel("Time (ms)")
plt.ylabel("Voltage (mV)")
# Out:
# Text(0, 0.5, 'Voltage (mV)')

# %% [markdown]
# ## Homework
#
# 1. Choose any active mouse cell model from the [database](http://celltypes.brain-map.org/data). When searching, put "Has All-active Biophysical model" on.
# 2. Simulate the cell for different values of current injection (CI). Plot voltage responses (t vs V) for each CI. Then plot the FI curve.
